# %%
import tensorflow as tf

keras = tf.keras
import pandas as pd, numpy as np
import os, unidecode, glob
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

from pylab import rcParams
rcParams['figure.figsize'] = (15, 8)

import math
from sklearn.metrics import mean_squared_error

# %%
if tf.test.gpu_device_name(): 
    print('Default GPU Device:{}'.format(tf.test.gpu_device_name()))
else:
   print("Please install GPU version of TF")
# Out:
# Default GPU Device:/device:GPU:0

# %%
check_df = pd.concat([pd.read_parquet(f) for f in glob.glob(os.path.dirname(os.getcwd())+'\\filtered_data\\checkin\\*.parquet')], ignore_index=True)

check_df['date'] = check_df.date.apply(lambda x: x.split(','))
check_df = check_df.explode('date').reset_index().drop('index',axis=1)
check_df['date'] = pd.to_datetime(check_df.date)

# %%
bus_df = pd.concat([pd.read_parquet(f) for f in glob.glob(os.path.dirname(os.getcwd())+'\\filtered_data\\business\\*.parquet')], ignore_index=True)

bus_df['city'] = bus_df.city.apply(lambda x: unidecode.unidecode(x))
bus_df['state'] = np.select(
    [
        bus_df['city'].isin(['Toronto', 'Richmond Hill', 'Scarborough', 'Markham', 'Mississauga', 'Brampton', 'Vaughan', 'North York']),
        bus_df['city'].isin(['Calgary']),
        bus_df['city'].isin(['Montreal']),
    ],
    [
        'ON',
        'AB',
        'QC'
    ]
)

# %%
df = bus_df[['business_id','city']].merge(check_df,on=['business_id'],how='inner')
df['city'] = df.city.astype('category')
df = df.assign(date=df.date.dt.round('H'))
df.head()
# Out:
#               business_id     city                date
# 0  EosRKXIGeSWFYWwpkbhNnA  Toronto 2012-06-12 19:00:00
# 1  EosRKXIGeSWFYWwpkbhNnA  Toronto 2013-02-11 15:00:00
# 2  EosRKXIGeSWFYWwpkbhNnA  Toronto 2013-02-22 18:00:00
# 3  EosRKXIGeSWFYWwpkbhNnA  Toronto 2013-03-05 21:00:00
# 4  EosRKXIGeSWFYWwpkbhNnA  Toronto 2013-03-06 17:00:00

# %%
pivot_df = df.pivot_table(index='date',values='business_id',columns='city',aggfunc='count', fill_value=0)
pivot_df.index = pd.DatetimeIndex(pivot_df.index)
pivot_df
# Out:
# city                 Brampton  Calgary  Markham  Mississauga  Montreal  \
# date
# 2010-01-16 02:00:00         0        1        0            0         0
# 2010-01-16 05:00:00         0        0        0            0         0
# 2010-01-16 10:00:00         0        0        0            0         0
# 2010-01-16 13:00:00         0        0        0            0         0
# 2010-01-16 15:00:00         0        1        0            0         0
# ...                       ...      ...      ...          ...       ...
# 2019-12-13 13:00:00         0        0        0            0         0
# 2019-12-13 14:00:00         0        0        0            0         0
# 2019-12-13 15:00:00         0        0        3            1         2
# 2019-12-13 16:00:00         0        1        0            1         1
# 2019-12-13 17:00:00         0        0        3            0         5
#
# city                 North York  Richmond Hill  Scarborough  Toronto  Vaughan
# date
# 2010-01-16 02:00:00           0              0            0        0        0
# 2010-01-16 05:00:00           0              0            0        1        0
# 2010-01-16 10:00:00           0              0            0        2        0
# 2010-01-16 13:00:00           0              0            0        1        0
# 2010-01-16 15:00:00           0              0            0        2        0
# ...                         ...            ...          ...      ...      ...
# 2019-12-13 13:00:00           1              1            0        4        0
# 2019-12-13 14:00:00           0              1            0        4        0
# 2019-12-13 15:00:00           0              0            0        5        0
# 2019-12-13 16:00:00           1              1            0        6        0
# 2019-12-13 17:00:00           0              1            1       19        1
#
# [78589 rows x 10 columns]

# %%
daily_tor = pivot_df.loc[:,'Toronto'].resample('D').sum().reset_index().rename(columns={'date':'ds','Toronto':'y'}).set_index('ds')

# %%
fig, ax = plt.subplots()
daily_tor.plot(ax=ax)
fig.suptitle('Daily checkins aggregate of businesses in Toronto')
ax.set(xlabel='time (daily)',ylabel=('number of checkins'))
plt.legend()
plt.show()

# %% [markdown]
# ## Forecasting

# %%
def train_test_split(ts_df):
    test_split = '2019-01-01'
    train = ts_df.loc[ts_df.index < test_split].copy()
    test = ts_df.loc[(ts_df.index >= test_split)].copy()
    print(train.shape)
    print(test.shape)
    return (train,test)

d_train, d_test = train_test_split(daily_tor.loc[daily_tor.index > '2012-12-31'])
val_size = d_test.shape[0]
error_vals = list()
# Out:
# (2191, 1)
# (347, 1)

# %%
def window_dataset(series, window_size, batch_size=32,
                   shuffle_buffer=1000):
    dataset = tf.data.Dataset.from_tensor_slices(series)
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))
    dataset = dataset.shuffle(shuffle_buffer)
    dataset = dataset.map(lambda window: (window[:-1], window[-1]))
    dataset = dataset.batch(batch_size).prefetch(1)
    return dataset

# %%
def model_forecast(model, series, window_size):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size))
    ds = ds.batch(32).prefetch(1)
    forecast = model.predict(ds)
    return forecast

# %% [markdown]
# ### Linear Model

# %%
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

window_size = 8
train_set = window_dataset(d_train[:-val_size].y, window_size)
valid_set = window_dataset(d_train[-val_size:].y, window_size)

lin_model = keras.models.Sequential([
  keras.layers.Dense(1, input_shape=[window_size])
])
optimizer = keras.optimizers.SGD(lr=1e-5, momentum=0.9)
lin_model.compile(loss=keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])
early_stopping = keras.callbacks.EarlyStopping(patience=10)
lin_model.fit(train_set, epochs=100,
          validation_data=valid_set,
          callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 58/58 [==============================] - 1s 21ms/step - loss: 303.9561 - mae: 306.9282 - val_loss: 74.8804 - val_mae: 75.3904
# Epoch 2/100
# 58/58 [==============================] - 0s 6ms/step - loss: 65.1184 - mae: 65.6470 - val_loss: 54.3712 - val_mae: 54.6605
# Epoch 3/100
# 58/58 [==============================] - 0s 6ms/step - loss: 52.3594 - mae: 52.8936 - val_loss: 47.3343 - val_mae: 48.4188
# Epoch 4/100
# 58/58 [==============================] - 0s 7ms/step - loss: 48.6259 - mae: 49.2172 - val_loss: 43.9578 - val_mae: 44.4851
# Epoch 5/100
# 58/58 [==============================] - 0s 7ms/step - loss: 45.8400 - mae: 46.4027 - val_loss: 42.5569 - val_mae: 42.6981
# Epoch 6/100
# 58/58 [==============================] - 0s 6ms/step - loss: 43.5021 - mae: 43.9836 - val_loss: 40.8349 - val_mae: 41.0139
# Epoch 7/100
# 58/58 [==============================] - 0s 7ms/step - loss: 42.8099 - mae: 43.4248 - val_loss: 38.5243 - val_mae: 39.3126
# Epoch 8/100
# 58/58 [==============================] - 0s 7ms/step - loss: 41.2088 - mae: 41.5610 - val_loss: 38.1055 - val_mae: 38.3511
# Epoch 9/100
# 58/58 [==============================] - 0s 7ms/step - loss: 39.9603 - mae: 40.4839 - val_loss: 39.2654 - val_mae: 39.6508
# Epoch 10/100
# 58/58 [==============================] - 0s 6ms/step - loss: 39.5065 - mae: 40.2219 - val_loss: 37.4989 - val_mae: 38.3096
# Epoch 11/100
# 58/58 [==============================] - 0s 6ms/step - loss: 39.7586 - mae: 40.1849 - val_loss: 35.2106 - val_mae: 35.7325
# Epoch 12/100
# 58/58 [==============================] - 0s 7ms/step - loss: 38.3760 - mae: 38.8993 - val_loss: 35.1497 - val_mae: 35.2550
# Epoch 13/100
# 58/58 [==============================] - 0s 7ms/step - loss: 37.8391 - mae: 38.4957 - val_loss: 34.3138 - val_mae: 34.8453
# Epoch 14/100
# 58/58 [==============================] - 0s 6ms/step - loss: 37.9696 - mae: 38.4672 - val_loss: 33.9320 - val_mae: 34.6010
# Epoch 15/100
# 58/58 [==============================] - 0s 7ms/step - loss: 37.4907 - mae: 38.1308 - val_loss: 34.2647 - val_mae: 34.3271
# Epoch 16/100
# 58/58 [==============================] - 0s 7ms/step - loss: 37.3110 - mae: 37.9281 - val_loss: 34.2745 - val_mae: 34.4845
# Epoch 17/100
# 58/58 [==============================] - 0s 7ms/step - loss: 37.6269 - mae: 37.9500 - val_loss: 33.6428 - val_mae: 34.4405
# Epoch 18/100
# 58/58 [==============================] - 0s 7ms/step - loss: 37.1929 - mae: 37.7615 - val_loss: 33.2841 - val_mae: 34.0157
# Epoch 19/100
# 58/58 [==============================] - 0s 7ms/step - loss: 37.1262 - mae: 37.4534 - val_loss: 33.0057 - val_mae: 33.9050
# Epoch 20/100
# 58/58 [==============================] - 0s 7ms/step - loss: 37.4149 - mae: 38.0146 - val_loss: 33.3393 - val_mae: 33.8642
# Epoch 21/100
# 58/58 [==============================] - 0s 7ms/step - loss: 36.8389 - mae: 37.2597 - val_loss: 33.5767 - val_mae: 34.2039
# Epoch 22/100
# 58/58 [==============================] - 0s 7ms/step - loss: 36.6597 - mae: 37.1206 - val_loss: 33.9899 - val_mae: 34.6069
# Epoch 23/100
# 58/58 [==============================] - 0s 7ms/step - loss: 36.6524 - mae: 37.1869 - val_loss: 33.3544 - val_mae: 33.8871
# Epoch 24/100
# 58/58 [==============================] - 0s 6ms/step - loss: 36.8759 - mae: 37.2034 - val_loss: 33.1059 - val_mae: 33.7264
# Epoch 25/100
# 58/58 [==============================] - 0s 8ms/step - loss: 37.1730 - mae: 37.6629 - val_loss: 35.0423 - val_mae: 35.6912
# Epoch 26/100
# 58/58 [==============================] - 0s 7ms/step - loss: 36.6492 - mae: 37.1074 - val_loss: 33.1398 - val_mae: 33.6650
# Epoch 27/100
# 58/58 [==============================] - 0s 7ms/step - loss: 36.5228 - mae: 37.0920 - val_loss: 33.8505 - val_mae: 33.7784
# Epoch 28/100
# 58/58 [==============================] - 0s 7ms/step - loss: 36.5738 - mae: 37.1986 - val_loss: 33.3691 - val_mae: 33.6201
# Epoch 29/100
# 58/58 [==============================] - 0s 7ms/step - loss: 36.8034 - mae: 37.2325 - val_loss: 33.2504 - val_mae: 33.9006

# %%
lin_predict = model_forecast(lin_model, d_train[-val_size-window_size:-1].y, window_size)[:, 0]
pred = pd.DataFrame(lin_predict, \
            index=d_train[-val_size:].index,
            columns=['prediction'])

fig, ax = plt.subplots()
d_train.plot(label='observed',ax=ax)
pred.plot(ax=ax)
plt.legend()
plt.show()

# %%
rmse_train = math.sqrt(mean_squared_error(d_train[-val_size:], pred.prediction))
print("The root mean squared error is {}.".format(rmse_train))
# Out:
# The root mean squared error is 45.48817018012076.

# %%
lin_forecast = model_forecast(lin_model, pd.concat([d_train[-window_size:],d_test[:-1]]).y, window_size)[:, 0]
fcast = pd.DataFrame(lin_forecast, \
            index=d_test.index,
            columns=['forecast'])

fig, ax = plt.subplots()
d_test.plot(ax=ax)
fcast.plot(ax=ax)
plt.legend()
plt.show()

# %%
rmse_test = math.sqrt(mean_squared_error(d_test, fcast))
print("The root mean squared error is {}.".format(rmse_test))
# Out:
# The root mean squared error is 42.628008049373605.

# %%
mape = np.mean(np.abs(d_test.values - fcast.values) / d_test.values) * 100
print("The mean average percentage error is {}.".format(mape))
# Out:
# The mean average percentage error is 14.114271773285921.

# %%
error_vals.append(('Linear Model',rmse_train,rmse_test,mape))

# %% [markdown]
# ### Dense Model

# %%
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

window_size = 8
train_set = window_dataset(d_train[:-val_size].y, window_size)
valid_set = window_dataset(d_train[-val_size:].y, window_size)

den_model = keras.models.Sequential([
  keras.layers.Dense(10, activation='relu', input_shape=[window_size]),
  keras.layers.Dense(10, activation='relu'),
  keras.layers.Dense(10, activation='relu'),
  keras.layers.Dense(1),
])
optimizer = keras.optimizers.SGD(lr=1e-5, momentum=0.9)
den_model.compile(loss=keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])
early_stopping = keras.callbacks.EarlyStopping(patience=10)
den_model.fit(train_set, epochs=200,
          validation_data=valid_set,
          callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 58/58 [==============================] - 1s 20ms/step - loss: 132.5901 - mae: 134.1635 - val_loss: 40.8264 - val_mae: 41.4995
# Epoch 2/200
# 58/58 [==============================] - 0s 7ms/step - loss: 39.0596 - mae: 39.2932 - val_loss: 41.9594 - val_mae: 42.4627
# Epoch 3/200
# 58/58 [==============================] - 0s 8ms/step - loss: 35.3109 - mae: 35.7916 - val_loss: 32.1767 - val_mae: 33.1478
# Epoch 4/200
# 58/58 [==============================] - 0s 7ms/step - loss: 34.7804 - mae: 35.3082 - val_loss: 32.7711 - val_mae: 33.4090
# Epoch 5/200
# 58/58 [==============================] - 1s 9ms/step - loss: 34.3802 - mae: 34.9318 - val_loss: 32.6744 - val_mae: 33.1032
# Epoch 6/200
# 58/58 [==============================] - 0s 8ms/step - loss: 34.1434 - mae: 34.6660 - val_loss: 32.9477 - val_mae: 33.4006
# Epoch 7/200
# 58/58 [==============================] - 0s 8ms/step - loss: 35.8164 - mae: 36.2698 - val_loss: 36.5444 - val_mae: 37.5774
# Epoch 8/200
# 58/58 [==============================] - 0s 9ms/step - loss: 33.6684 - mae: 34.1895 - val_loss: 32.1710 - val_mae: 32.5139
# Epoch 9/200
# 58/58 [==============================] - 0s 8ms/step - loss: 33.6963 - mae: 34.1849 - val_loss: 34.0472 - val_mae: 34.5433
# Epoch 10/200
# 58/58 [==============================] - 1s 9ms/step - loss: 33.5067 - mae: 34.1466 - val_loss: 30.7664 - val_mae: 31.3944
# Epoch 11/200
# 58/58 [==============================] - 0s 8ms/step - loss: 34.6975 - mae: 35.1667 - val_loss: 34.6368 - val_mae: 35.0681
# Epoch 12/200
# 58/58 [==============================] - 0s 8ms/step - loss: 33.1297 - mae: 33.6799 - val_loss: 34.7477 - val_mae: 35.1082
# Epoch 13/200
# 58/58 [==============================] - 1s 9ms/step - loss: 34.0543 - mae: 34.6654 - val_loss: 30.6057 - val_mae: 31.2330
# Epoch 14/200
# 58/58 [==============================] - 0s 9ms/step - loss: 33.2813 - mae: 33.7173 - val_loss: 32.9115 - val_mae: 33.5986
# Epoch 15/200
# 58/58 [==============================] - 0s 8ms/step - loss: 34.6081 - mae: 35.2937 - val_loss: 32.1082 - val_mae: 32.2630
# Epoch 16/200
# 58/58 [==============================] - 1s 9ms/step - loss: 32.6673 - mae: 33.2308 - val_loss: 31.7131 - val_mae: 32.0593
# Epoch 17/200
# 58/58 [==============================] - 0s 8ms/step - loss: 34.0264 - mae: 34.4308 - val_loss: 33.2049 - val_mae: 33.9794
# Epoch 18/200
# 58/58 [==============================] - 0s 8ms/step - loss: 32.5422 - mae: 33.1626 - val_loss: 30.6897 - val_mae: 31.1471
# Epoch 19/200
# 58/58 [==============================] - 0s 8ms/step - loss: 33.6142 - mae: 34.0503 - val_loss: 31.3595 - val_mae: 32.1833
# Epoch 20/200
# 58/58 [==============================] - 0s 8ms/step - loss: 32.5344 - mae: 33.0859 - val_loss: 30.6328 - val_mae: 31.0389
# Epoch 21/200
# 58/58 [==============================] - 0s 9ms/step - loss: 32.4549 - mae: 32.8877 - val_loss: 31.1530 - val_mae: 31.7263
# Epoch 22/200
# 58/58 [==============================] - 0s 8ms/step - loss: 32.4491 - mae: 32.8474 - val_loss: 33.4509 - val_mae: 33.9710
# Epoch 23/200
# 58/58 [==============================] - 0s 9ms/step - loss: 32.4249 - mae: 33.0273 - val_loss: 32.6965 - val_mae: 33.0407

# %%
dense_predict = model_forecast(den_model, d_train[-val_size-window_size:-1].y, window_size)[:, 0]
pred = pd.DataFrame(dense_predict, \
            index=d_train[-val_size:].index,
            columns=['prediction'])

fig, ax = plt.subplots()
d_train.plot(label='observed',ax=ax)
pred.plot(ax=ax)
plt.legend()
plt.show()

# %%
rmse_train = math.sqrt(mean_squared_error(d_train[-val_size:], pred.prediction))
print("The root mean squared error is {}.".format(rmse_train))
# Out:
# The root mean squared error is 42.97472943958319.

# %%
dense_forecast = model_forecast(den_model, pd.concat([d_train[-window_size:],d_test[:-1]]).y, window_size)[:, 0]
fcast = pd.DataFrame(dense_forecast, \
            index=d_test.index,
            columns=['forecast'])

fig, ax = plt.subplots()
d_test.plot(ax=ax)
fcast.plot(ax=ax)
plt.legend()
plt.show()

# %%
rmse_test = math.sqrt(mean_squared_error(d_test, fcast))
print("The root mean squared error is {}.".format(rmse_test))
# Out:
# The root mean squared error is 40.88617557344262.

# %%
mape = np.mean(np.abs(d_test.y.values - fcast.forecast.values) / d_test.y.values) * 100
print("The mean average percentage error is {}.".format(mape))
# Out:
# The mean average percentage error is 14.012982221092042.

# %%
error_vals.append(('Dense Model',rmse_train,rmse_test,mape))

# %% [markdown]
# ### CNN Model

# %%
def seq2seq_window_dataset(series, window_size, batch_size=32,
                           shuffle_buffer=1000):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.shuffle(shuffle_buffer)
    ds = ds.map(lambda w: (w[:-1], w[1:]))
    return ds.batch(batch_size).prefetch(1)

ts_model_path = os.path.dirname(os.getcwd())+'\\saved_models\\time_series'
if not os.path.exists(ts_model_path):
    os.makedirs(ts_model_path)

# %%
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

window_size = 8
train_set = seq2seq_window_dataset(d_train[:-val_size].y, window_size,
                                   batch_size=32)
valid_set = seq2seq_window_dataset(d_train[-val_size:].y, window_size,
                                   batch_size=32)

model = keras.models.Sequential([
  keras.layers.Conv1D(filters=32, kernel_size=3,
                      strides=1, padding="causal",
                      activation="relu",
                      input_shape=[None, 1]),
  keras.layers.LSTM(32, return_sequences=True),
  keras.layers.LSTM(32, return_sequences=True),
  keras.layers.Dense(1),
  keras.layers.Lambda(lambda x: x * 
# Epoch 123/500
# 58/58 [==============================] - 1s 14ms/step - loss: 51.5589 - mae: 52.1132 - val_loss: 53.1358 - val_mae: 53.5877
# Epoch 124/500
# 58/58 [==============================] - 1s 13ms/step - loss: 51.6605 - mae: 52.1380 - val_loss: 50.1562 - val_mae: 50.8588
# Epoch 125/500
# 58/58 [==============================] - 1s 13ms/step - loss: 51.8412 - mae: 52.3651 - val_loss: 49.2307 - val_mae: 49.6183
# Epoch 126/500
# 58/58 [==============================] - 1s 12ms/step - loss: 51.5025 - mae: 51.9899 - val_loss: 50.9159 - val_mae: 51.3192
# Epoch 127/500
# 58/58 [==============================] - 1s 14ms/step - loss: 51.4560 - mae: 51.8971 - val_loss: 53.0525 - val_mae: 53.6476
# Epoch 128/500
# 58/58 [==============================] - 1s 12ms/step - loss: 51.2862 - mae: 51.7959 - val_loss: 49.0753 - val_mae: 49.6739

# %%
cnn_model = keras.models.load_model(os.path.join(ts_model_path,"cnn_checkpoint.h5"))

# %%
cnn_predict = model_forecast(cnn_model, d_train.y.values[:, np.newaxis], window_size)
pred = pd.DataFrame(cnn_predict[-val_size:, -1, 0], \
            index=d_train[-val_size:].index,
            columns=['prediction'])

fig, ax = plt.subplots()
d_train.plot(label='observed',ax=ax)
pred.plot(ax=ax)
plt.legend()
plt.show()

# %%
rmse_train = math.sqrt(mean_squared_error(d_train[-val_size:], pred.prediction))
print("The root mean squared error is {}.".format(rmse_train))
# Out:
# The root mean squared error is 79.11704158308733.

# %%
cnn_forecast = model_forecast(cnn_model, pd.concat([d_train[-window_size:-1],d_test]).y.values[:, np.newaxis], window_size)
fcast = pd.DataFrame(cnn_forecast[:,-1,0], \
            index=d_test.index,
            columns=['forecast'])

fig, ax = plt.subplots()
d_test.plot(ax=ax)
fcast.plot(ax=ax)
plt.legend()
plt.show()

# %%
rmse_test = math.sqrt(mean_squared_error(d_test, fcast))
print("The root mean squared error is {}.".format(rmse_test))
# Out:
# The root mean squared error is 64.41174207286797.

# %%
mape = np.mean(np.abs(d_test.y.values - fcast.forecast.values) / d_test.y.values) * 100
print("The mean average percentage error is {}.".format(mape))
# Out:
# The mean average percentage error is 16.35111261400622.

# %%
error_vals.append(('CNN Model',rmse_train,rmse_test,mape))

# %% [markdown]
# ### WaveNet

# %%
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

window_size = 8
train_set = seq2seq_window_dataset(d_train[:-val_size].y, window_size,
                                   batch_size=32)
valid_set = seq2seq_window_dataset(d_train[-val_size:].y, window_size,
                                   batch_size=32)

model = keras.models.Sequential()
model.add(keras.layers.InputLayer(input_shape=[None, 1]))
for dilation_rate in (1, 2, 4, 8, 16, 32):
    model.add(
      keras.layers.Conv1D(filters=32,
                          kernel_size=2,
                          strides=1,
                          dilation_rate=dilation_rate,
                          padding="causal",
                          activation="relu")
    )
model.add(keras.layers.Conv1D(filters=1, kernel_size=1))
optimizer = keras.optimizers.Adam(lr=3e-4)
model.compile(loss=keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

model_checkpoint = keras.callbacks.ModelCheckpoint(
    os.path.join(ts_model_path,"wnet_checkpoint.h5"), save_best_only=True)
early_stopping = keras.callbacks.EarlyStopping(patience=50)
history = model.fit(train_set, epochs=500,
                    validation_data=valid_set,
                    callbacks=[early_stopping, model_checkpoint])
# Out:
# =======================] - 1s 17ms/step - loss: 43.2055 - mae: 43.6653 - val_loss: 41.4565 - val_mae: 41.9343
# Epoch 119/500
# 58/58 [==============================] - 1s 17ms/step - loss: 42.9425 - mae: 43.4557 - val_loss: 41.4993 - val_mae: 42.1681
# Epoch 120/500
# 58/58 [==============================] - 1s 19ms/step - loss: 43.1718 - mae: 43.6416 - val_loss: 41.0248 - val_mae: 41.5292
# Epoch 121/500
# 58/58 [==============================] - 1s 16ms/step - loss: 43.0007 - mae: 43.5272 - val_loss: 41.4910 - val_mae: 41.8791
# Epoch 122/500
# 58/58 [==============================] - 1s 17ms/step - loss: 43.3221 - mae: 43.7407 - val_loss: 41.4565 - val_mae: 41.9214
# Epoch 123/500
# 58/58 [==============================] - 1s 16ms/step - loss: 43.1923 - mae: 43.7380 - val_loss: 41.9667 - val_mae: 42.2440
# Epoch 124/500
# 58/58 [==============================] - 1s 16ms/step - loss: 43.1927 - mae: 43.7253 - val_loss: 41.1403 - val_mae: 41.6893
# Epoch 125/500
# 58/58 [==============================] - 1s 17ms/step - loss: 43.1169 - mae: 43.5744 - val_loss: 42.2132 - val_mae: 42.6816
# Epoch 126/500
# 58/58 [==============================] - 1s 18ms/step - loss: 42.9328 - mae: 43.4215 - val_loss: 41.4158 - val_mae: 41.8675
# Epoch 127/500
# 58/58 [==============================] - 1s 17ms/step - loss: 42.8958 - mae: 43.3359 - val_loss: 41.3329 - val_mae: 41.9725
# Epoch 128/500
# 58/58 [==============================] - 1s 19ms/step - loss: 42.8044 - mae: 43.2727 - val_loss: 40.5076 - val_mae: 41.1065
# Epoch 129/500
# 58/58 [==============================] - 1s 17ms/step - loss: 42.8512 - mae: 43.3634 - val_loss: 41.7673 - val_mae: 42.2790
# Epoch 130/500
# 58/58 [==============================] - 1s 16ms/step - loss: 43.0520 - mae: 43.5408 - val_loss: 41.1972 - val_mae: 41.8562
# Epoch 131/500
# 58/58 [==============================] - 1s 14ms/step - loss: 42.8479 - mae: 43.3311 - val_loss: 41.7253 - val_mae: 42.0449
# Epoch 132/500
# 58/58 [==============================] - 1s 16ms/step - loss: 42.8024 - mae: 43.2407 - val_loss: 42.0258 - val_mae: 42.5441
# Epoch 133/500
# 58/58 [==============================] - 1s 15ms/step - loss: 42.8548 - mae: 43.4145 - val_loss: 41.1664 - val_mae: 41.6101
# Epoch 134/500
# 58/58 [==============================] - 1s 13ms/step - loss: 42.8392 - mae: 43.3795 - val_loss: 41.1273 - val_mae: 41.4156
# Epoch 135/500
# 58/58 [==============================] - 1s 14ms/step - loss: 42.6389 - mae: 43.1763 - val_loss: 42.4016 - val_mae: 43.0027
# Epoch 136/500
# 58/58 [==============================] - 1s 16ms/step - loss: 42.6920 - mae: 43.1661 - val_loss: 41.0673 - val_mae: 41.7219
# Epoch 137/500
# 58/58 [==============================] - 1s 14ms/step - loss: 42.7419 - mae: 43.1808 - val_loss: 42.7360 - val_mae: 43.2492
# Epoch 138/500
# 58/58 [==============================] - 1s 14ms/step - loss: 42.8203 - mae: 43.2658 - val_loss: 41.4126 - val_mae: 42.0684
# Epoch 139/500
# 58/58 [==============================] - 1s 14ms/step - loss: 42.7929 - mae: 43.3508 - val_loss: 41.1722 - val_mae: 41.6431
# Epoch 140/500
# 58/58 [==============================] - 1s 14ms/step - loss: 42.6296 - mae: 43.1408 - val_loss: 41.1570 - val_mae: 41.6111
# Epoch 141/500
# 58/58 [==============================] - 1s 14ms/step - loss: 43.2615 - mae: 43.6655 - val_loss: 41.6851 - val_mae: 42.2695
# Epoch 142/500
# 58/58 [==============================] - 1s 15ms/step - loss: 43.0068 - mae: 43.5817 - val_loss: 41.8925 - val_mae: 42.4140
# Epoch 143/500
# 58/58 [==============================] - 1s 14ms/step - loss: 42.9211 - mae: 43.4369 - val_loss: 40.7678 - val_mae: 41.3695
# Epoch 144/500
# 58/58 [==============================] - 1s 15ms/step - loss: 42.6761 - mae: 43.1455 - val_loss: 41.4564 - val_mae: 41.8689
# Epoch 145/500
# 58/58 [==============================] - 1s 13ms/step - loss: 42.7489 - mae: 43.2369 - val_loss: 42.0616 - val_mae: 42.3868
# Epoch 146/500
# 58/58 [==============================] - 1s 15ms/step - loss: 42.8841 - mae: 43.2777 - val_loss: 42.2780 - val_mae: 42.7652
# Epoch 147/500
# 58/58 [==============================] - 1s 14ms/step - loss: 42.4889 - mae: 43.0269 - val_loss: 41.5077 - val_mae: 41.9072
# Epoch 148/500
# 58/58 [==============================] - 1s 14ms/step - loss: 42.6340 - mae: 43.1047 - val_loss: 40.6876 - val_mae: 40.9986
# Epoch 149/500
# 58/58 [==============================] - 1s 14ms/step - loss: 42.7092 - mae: 43.2471 - val_loss: 40.6114 - val_mae: 41.0514
# Epoch 150/500
# 58/58 [==============================] - 1s 13ms/step - loss: 42.6005 - mae: 43.1331 - val_loss: 40.8821 - val_mae: 41.3335
# Epoch 151/500
# 58/58 [==============================] - 1s 13ms/step - loss: 42.6863 - mae: 43.1403 - val_loss: 42.4276 - val_mae: 43.0288
# Epoch 152/500
# 58/58 [==============================] - 1s 13ms/step - loss: 42.9354 - mae: 43.4729 - val_loss: 41.0711 - val_mae: 41.6572
# Epoch 153/500
# 58/58 [==============================] - 1s 14ms/step - loss: 42.6641 - mae: 43.0864 - val_loss: 41.4007 - val_mae: 41.9382
# Epoch 154/500
# 58/58 [==============================] - 1s 15ms/step - loss: 42.6496 - mae: 43.1249 - val_loss: 43.9775 - val_mae: 44.1950
# Epoch 155/500
# 58/58 [==============================] - 1s 16ms/step - loss: 42.5988 - mae: 43.1183 - val_loss: 40.7233 - val_mae: 41.0969
# Epoch 156/500
# 58/58 [==============================] - 1s 14ms/step - loss: 42.4235 - mae: 42.9509 - val_loss: 41.1802 - val_mae: 41.6321
# Epoch 157/500
# 58/58 [==============================] - 1s 17ms/step - loss: 42.3284 - mae: 42.8838 - val_loss: 43.0418 - val_mae: 43.5164
# Epoch 158/500
# 58/58 [==============================] - 2s 35ms/step - loss: 42.4874 - mae: 42.9532 - val_loss: 40.7566 - val_mae: 41.4047
# Epoch 159/500
# 58/58 [==============================] - 2s 28ms/step - loss: 42.4049 - mae: 42.9003 - val_loss: 40.7018 - val_mae: 41.2849
# Epoch 160/500
# 58/58 [==============================] - 2s 27ms/step - loss: 42.3962 - mae: 42.8036 - val_loss: 41.1911 - val_mae: 41.8227
# Epoch 161/500
# 58/58 [==============================] - 2s 30ms/step - loss: 42.3799 - mae: 42.8432 - val_loss: 41.8012 - val_mae: 42.3235
# Epoch 162/500
# 58/58 [==============================] - 2s 27ms/step - loss: 42.3821 - mae: 42.9058 - val_loss: 40.5493 - val_mae: 41.0944
# Epoch 163/500
# 58/58 [==============================] - 2s 27ms/step - loss: 42.5413 - mae: 43.0195 - val_loss: 41.3307 - val_mae: 41.8060
# Epoch 164/500
# 58/58 [==============================] - 2s 26ms/step - loss: 42.6196 - mae: 42.9555 - val_loss: 41.1639 - val_mae: 41.5992
# Epoch 165/500
# 58/58 [==============================] - 2s 26ms/step - loss: 42.3736 - mae: 42.8868 - val_loss: 40.8419 - val_mae: 41.2838
# Epoch 166/500
# 58/58 [==============================] - 2s 29ms/step - loss: 42.2695 - mae: 42.7489 - val_loss: 40.8704 - val_mae: 41.2853
# Epoch 167/500
# 58/58 [==============================] - 2s 26ms/step - loss: 42.3854 - mae: 42.9000 - val_loss: 42.1596 - val_mae: 42.6170
# Epoch 168/500
# 58/58 [==============================] - 2s 27ms/step - loss: 42.1480 - mae: 42.6253 - val_loss: 41.4928 - val_mae: 41.9632
# Epoch 169/500
# 58/58 [==============================] - 2s 33ms/step - loss: 42.1949 - mae: 42.7197 - val_loss: 41.6327 - val_mae: 42.1355
# Epoch 170/500
# 58/58 [==============================] - 2s 32ms/step - loss: 42.1896 - mae: 42.6199 - val_loss: 42.2723 - val_mae: 42.8559
# Epoch 171/500
# 58/58 [==============================] - 1s 25ms/step - loss: 42.4192 - mae: 42.9330 - val_loss: 40.6754 - val_mae: 41.3586
# Epoch 172/500
# 58/58 [==============================] - 1s 23ms/step - loss: 42.4014 - mae: 42.9221 - val_loss: 42.8637 - val_mae: 43.2271
# Epoch 173/500
# 58/58 [==============================] - 1s 23ms/step - loss: 42.4034 - mae: 42.9242 - val_loss: 42.3024 - val_mae: 42.8693
# Epoch 174/500
# 58/58 [==============================] - 1s 23ms/step - loss: 42.1997 - mae: 42.6329 - val_loss: 40.9262 - val_mae: 41.4379
# Epoch 175/500
# 58/58 [==============================] - 1s 23ms/step - loss: 42.0138 - mae: 42.5858 - val_loss: 41.2720 - val_mae: 41.5955
# Epoch 176/500
# 58/58 [==============================] - 1s 23ms/step - loss: 42.1870 - mae: 42.7336 - val_loss: 42.0141 - val_mae: 42.3350
# Epoch 177/500
# 58/58 [==============================] - 2s 30ms/step - loss: 42.0195 - mae: 42.5410 - val_loss: 40.3891 - val_mae: 40.9021
# Epoch 178/500
# 58/58 [==============================] - 1s 23ms/step - loss: 42.1036 - mae: 42.5837 - val_loss: 41.5454 - val_mae: 41.8952
# Epoch 179/500
# 58/58 [==============================] - 1s 23ms/step - loss: 42.1457 - mae: 42.5713 - val_loss: 42.3288 - val_mae: 42.8839
# Epoch 180/500
# 58/58 [==============================] - 1s 23ms/step - loss: 42.1929 - mae: 42.7025 - val_loss: 40.8701 - val_mae: 41.3960
# Epoch 181/500
# 58/58 [==============================] - 1s 23ms/step - loss: 41.9965 - mae: 42.5412 - val_loss: 40.6065 - val_mae: 41.2024
# Epoch 182/500
# 58/58 [==============================] - 1s 24ms/step - loss: 42.1503 - mae: 42.6110 - val_loss: 41.0783 - val_mae: 41.5327
# Epoch 183/500
# 58/58 [==============================] - 1s 23ms/step - loss: 42.1372 - mae: 42.5256 - val_loss: 42.5955 - val_mae: 42.9577
# Epoch 184/500
# 58/58 [==============================] - 1s 24ms/step - loss: 42.0052 - mae: 42.4690 - val_loss: 40.6009 - val_mae: 41.2079
# Epoch 185/500
# 58/58 [==============================] - 1s 23ms/step - loss: 42.3713 - mae: 42.7980 - val_loss: 40.4718 - val_mae: 41.0124
# Epoch 186/500
# 58/58 [==============================] - 1s 23ms/step - loss: 42.1861 - mae: 42.6466 - val_loss: 41.0653 - val_mae: 41.6515
# Epoch 187/500
# 58/58 [==============================] - 1s 23ms/step - loss: 42.1986 - mae: 42.6770 - val_loss: 41.1041 - val_mae: 41.3206
# Epoch 188/500
# 58/58 [==============================] - 1s 24ms/step - loss: 41.9943 - mae: 42.4601 - val_loss: 40.8699 - val_mae: 41.3686
# Epoch 189/500
# 55/58 [===========================>..] - ETA: 0s - loss: 42.1252 - mae: 42.62158/58 [==============================] - 1s 24ms/step - loss: 42.0584 - mae: 42.6174 - val_loss: 41.0326 - val_mae: 41.4336
# Epoch 190/500
# 58/58 [==============================] - 1s 25ms/step - loss: 42.1353 - mae: 42.6233 - val_loss: 41.2395 - val_mae: 41.8108
# Epoch 191/500
# 58/58 [==============================] - 1s 24ms/step - loss: 42.1089 - mae: 42.5155 - val_loss: 42.2896 - val_mae: 42.7104
# Epoch 192/500
# 58/58 [==============================] - 1s 24ms/step - loss: 41.9447 - mae: 42.4989 - val_loss: 41.9941 - val_mae: 42.3103
# Epoch 193/500
# 58/58 [==============================] - 1s 23ms/step - loss: 42.0280 - mae: 42.5639 - val_loss: 40.9267 - val_mae: 41.4144
# Epoch 194/500
# 58/58 [==============================] - 2s 31ms/step - loss: 41.9474 - mae: 42.3993 - val_loss: 40.3637 - val_mae: 40.9280
# Epoch 195/500
# 58/58 [==============================] - 2s 27ms/step - loss: 41.8386 - mae: 42.3611 - val_loss: 41.9988 - val_mae: 42.5582
# Epoch 196/500
# 58/58 [==============================] - 2s 27ms/step - loss: 41.9284 - mae: 42.3780 - val_loss: 40.1821 - val_mae: 40.5855
# Epoch 197/500
# 58/58 [==============================] - 2s 27ms/step - loss: 41.9217 - mae: 42.3450 - val_loss: 41.1495 - val_mae: 41.6884
# Epoch 198/500
# 58/58 [==============================] - 1s 25ms/step - loss: 42.0846 - mae: 42.5843 - val_loss: 41.0963 - val_mae: 41.5940
# Epoch 199/500
# 58/58 [==============================] - 2s 27ms/step - loss: 41.7180 - mae: 42.2688 - val_loss: 39.8955 - val_mae: 40.3386
# Epoch 200/500
# 58/58 [==============================] - 1s 24ms/step - loss: 41.7745 - mae: 42.3320 - val_loss: 40.3960 - val_mae: 40.8469
# Epoch 201/500
# 58/58 [==============================] - 2s 26ms/step - loss: 41.9596 - mae: 42.3630 - val_loss: 40.4863 - val_mae: 40.9249
# Epoch 202/500
# 58/58 [==============================] - 2s 27ms/step - loss: 41.7149 - mae: 42.2141 - val_loss: 41.1673 - val_mae: 41.5066
# Epoch 203/500
# 58/58 [==============================] - 2s 31ms/step - loss: 41.9804 - mae: 42.4571 - val_loss: 41.0995 - val_mae: 41.6529
# Epoch 204/500
# 58/58 [==============================] - 2s 33ms/step - loss: 42.0112 - mae: 42.3985 - val_loss: 41.2331 - val_mae: 41.8047
# Epoch 205/500
# 58/58 [==============================] - 2s 32ms/step - loss: 42.0699 - mae: 42.5304 - val_loss: 40.4660 - val_mae: 41.0334
# Epoch 206/500
# 58/58 [==============================] - 2s 26ms/step - loss: 41.9843 - mae: 42.4077 - val_loss: 40.4186 - val_mae: 40.9757
# Epoch 207/500
# 58/58 [==============================] - 2s 26ms/step - loss: 41.6107 - mae: 42.1151 - val_loss: 41.1259 - val_mae: 41.5864
# Epoch 208/500
# 58/58 [==============================] - 1s 13ms/step - loss: 41.7599 - mae: 42.2047 - val_loss: 41.2456 - val_mae: 41.8337
# Epoch 209/500
# 58/58 [==============================] - 1s 13ms/step - loss: 41.9416 - mae: 42.4542 - val_loss: 41.1137 - val_mae: 41.6801
# Epoch 210/500
# 58/58 [==============================] - 1s 16ms/step - loss: 41.6893 - mae: 42.2167 - val_loss: 41.1793 - val_mae: 41.6633
# Epoch 211/500
# 58/58 [==============================] - 1s 18ms/step - loss: 41.6035 - mae: 42.1405 - val_loss: 39.6604 - val_mae: 40.1441
# Epoch 212/500
# 58/58 [==============================] - 1s 12ms/step - loss: 41.8041 - mae: 42.2166 - val_loss: 40.7448 - val_mae: 41.0540
# Epoch 213/500
# 58/58 [==============================] - 1s 14ms/step - loss: 41.9284 - mae: 42.4013 - val_loss: 42.0543 - val_mae: 42.5376
# Epoch 214/500
# 58/58 [==============================] - 1s 13ms/step - loss: 41.8245 - mae: 42.2907 - val_loss: 41.4458 - val_mae: 42.0624
# Epoch 215/500
# 58/58 [==============================] - 1s 14ms/step - loss: 41.7693 - mae: 42.2373 - val_loss: 40.4290 - val_mae: 40.9221
# Epoch 216/500
# 58/58 [==============================] - 1s 16ms/step - loss: 41.5805 - mae: 42.0733 - val_loss: 41.0607 - val_mae: 41.6188
# Epoch 217/500
# 58/58 [==============================] - 1s 15ms/step - loss: 41.8616 - mae: 42.3989 - val_loss: 41.0717 - val_mae: 41.4177
# Epoch 218/500
# 58/58 [==============================] - 1s 12ms/step - loss: 41.9161 - mae: 42.3322 - val_loss: 41.1306 - val_mae: 41.5087
# Epoch 219/500
# 58/58 [==============================] - 1s 12ms/step - loss: 41.7879 - mae: 42.2594 - val_loss: 40.9801 - val_mae: 41.4362
# Epoch 220/500
# 58/58 [==============================] - 1s 13ms/step - loss: 41.8660 - mae: 42.3217 - val_loss: 41.0462 - val_mae: 41.4050
# Epoch 221/500
# 58/58 [==============================] - 1s 14ms/step - loss: 41.6531 - mae: 42.1732 - val_loss: 40.6540 - val_mae: 41.1105
# Epoch 222/500
# 58/58 [==============================] - 1s 13ms/step - loss: 41.5003 - mae: 42.0559 - val_loss: 40.1163 - val_mae: 40.7994
# Epoch 223/500
# 58/58 [==============================] - 1s 15ms/step - loss: 41.7102 - mae: 42.2346 - val_loss: 40.5026 - val_mae: 41.1022
# Epoch 224/500
# 58/58 [==============================] - 1s 13ms/step - loss: 41.7414 - mae: 42.1987 - val_loss: 41.3158 - val_mae: 41.9641
# Epoch 225/500
# 58/58 [==============================] - 1s 19ms/step - loss: 41.4555 - mae: 41.9578 - val_loss: 41.4854 - val_mae: 41.8892
# Epoch 226/500
# 58/58 [==============================] - 1s 16ms/step - loss: 41.8137 - mae: 42.3463 - val_loss: 40.4753 - val_mae: 40.7972
# Epoch 227/500
# 58/58 [==============================] - 1s 21ms/step - loss: 41.4215 - mae: 41.9631 - val_loss: 40.3386 - val_mae: 40.9484
# Epoch 228/500
# 58/58 [==============================] - 1s 13ms/step - loss: 41.5897 - mae: 42.0177 - val_loss: 41.2090 - val_mae: 41.7640
# Epoch 229/500
# 58/58 [==============================] - 1s 13ms/step - loss: 41.6398 - mae: 42.0686 - val_loss: 41.1246 - val_mae: 41.5256
# Epoch 230/500
# 58/58 [==============================] - 1s 13ms/step - loss: 41.4935 - mae: 42.0372 - val_loss: 40.0044 - val_mae: 40.6091
# Epoch 231/500
# 58/58 [==============================] - 1s 21ms/step - loss: 41.5184 - mae: 42.0016 - val_loss: 40.3261 - val_mae: 40.7310
# Epoch 232/500
# 58/58 [==============================] - 1s 19ms/step - loss: 41.5703 - mae: 42.0655 - val_loss: 40.8840 - val_mae: 41.1659
# Epoch 233/500
# 58/58 [==============================] - 1s 18ms/step - loss: 41.7266 - mae: 42.1650 - val_loss: 41.4477 - val_mae: 41.9916
# Epoch 234/500
# 58/58 [==============================] - 1s 20ms/step - loss: 41.4452 - mae: 41.9816 - val_loss: 40.6833 - val_mae: 41.1607
# Epoch 235/500
# 58/58 [==============================] - 1s 19ms/step - loss: 41.3684 - mae: 41.8546 - val_loss: 40.3591 - val_mae: 40.8792
# Epoch 236/500
# 58/58 [==============================] - 1s 18ms/step - loss: 41.3647 - mae: 41.8692 - val_loss: 41.1462 - val_mae: 41.5968
# Epoch 237/500
# 58/58 [==============================] - 1s 18ms/step - loss: 41.5346 - mae: 42.0329 - val_loss: 40.6679 - val_mae: 41.1756
# Epoch 238/500
# 58/58 [==============================] - 1s 19ms/step - loss: 41.5136 - mae: 41.9963 - val_loss: 40.9997 - val_mae: 41.4860
# Epoch 239/500
# 58/58 [==============================] - 1s 17ms/step - loss: 41.5656 - mae: 42.0947 - val_loss: 41.6824 - val_mae: 42.1083
# Epoch 240/500
# 58/58 [==============================] - 1s 19ms/step - loss: 41.5669 - mae: 42.0650 - val_loss: 41.2878 - val_mae: 41.8039
# Epoch 241/500
# 58/58 [==============================] - 1s 17ms/step - loss: 41.5707 - mae: 42.0621 - val_loss: 40.7119 - val_mae: 41.1364
# Epoch 242/500
# 58/58 [==============================] - 1s 18ms/step - loss: 41.3792 - mae: 41.9150 - val_loss: 40.2178 - val_mae: 40.6684
# Epoch 243/500
# 58/58 [==============================] - 1s 17ms/step - loss: 41.6564 - mae: 42.0803 - val_loss: 41.9714 - val_mae: 42.5172
# Epoch 244/500
# 58/58 [==============================] - 1s 17ms/step - loss: 41.4226 - mae: 41.9096 - val_loss: 40.8782 - val_mae: 41.3144
# Epoch 245/500
# 58/58 [==============================] - 1s 18ms/step - loss: 41.3277 - mae: 41.8527 - val_loss: 40.3752 - val_mae: 40.7895
# Epoch 246/500
# 58/58 [==============================] - 1s 17ms/step - loss: 41.4863 - mae: 41.9345 - val_loss: 41.7798 - val_mae: 42.0183
# Epoch 247/500
# 58/58 [==============================] - 1s 17ms/step - loss: 41.6680 - mae: 42.1261 - val_loss: 40.7287 - val_mae: 41.3554
# Epoch 248/500
# 58/58 [==============================] - 1s 18ms/step - loss: 41.4751 - mae: 41.9992 - val_loss: 40.9531 - val_mae: 41.5289
# Epoch 249/500
# 58/58 [==============================] - 1s 18ms/step - loss: 41.3886 - mae: 41.9099 - val_loss: 41.0965 - val_mae: 41.6196
# Epoch 250/500
# 58/58 [==============================] - 1s 18ms/step - loss: 41.5169 - mae: 41.9945 - val_loss: 40.7114 - val_mae: 41.2960
# Epoch 251/500
# 58/58 [==============================] - 1s 17ms/step - loss: 41.5700 - mae: 42.0361 - val_loss: 40.3527 - val_mae: 40.8514
# Epoch 252/500
# 58/58 [==============================] - 1s 17ms/step - loss: 41.2721 - mae: 41.8364 - val_loss: 40.5830 - val_mae: 41.0032
# Epoch 253/500
# 58/58 [==============================] - 1s 18ms/step - loss: 41.4789 - mae: 41.9420 - val_loss: 41.0770 - val_mae: 41.5764
# Epoch 254/500
# 58/58 [==============================] - 1s 18ms/step - loss: 41.5704 - mae: 42.0829 - val_loss: 40.9579 - val_mae: 41.3645
# Epoch 255/500
# 58/58 [==============================] - 1s 18ms/step - loss: 41.1788 - mae: 41.6465 - val_loss: 40.9443 - val_mae: 41.3894
# Epoch 256/500
# 58/58 [==============================] - 1s 18ms/step - loss: 41.4438 - mae: 41.9635 - val_loss: 40.9680 - val_mae: 41.3783
# Epoch 257/500
# 58/58 [==============================] - 1s 17ms/step - loss: 41.2847 - mae: 41.8042 - val_loss: 40.0995 - val_mae: 40.5549
# Epoch 258/500
# 58/58 [==============================] - 1s 17ms/step - loss: 41.4363 - mae: 41.8618 - val_loss: 41.4974 - val_mae: 42.0091
# Epoch 259/500
# 58/58 [==============================] - 1s 17ms/step - loss: 41.8325 - mae: 42.2852 - val_loss: 41.9652 - val_mae: 42.4169
# Epoch 260/500
# 56/58 [===========================>..] - ETA: 0s - loss: 41.3421 - mae: 41.83858/58 [==============================] - 1s 18ms/step - loss: 41.3817 - mae: 41.8331 - val_loss: 40.5471 - val_mae: 41.0686
# Epoch 261/500
# 58/58 [==============================] - 1s 19ms/step - loss: 41.2158 - mae: 41.7088 - val_loss: 40.1406 - val_mae: 40.7275

# %%
wnet_model = keras.models.load_model(os.path.join(ts_model_path,"wnet_checkpoint.h5"))

# %%
wnet_predict = model_forecast(wnet_model, d_train.y.values[:, np.newaxis], window_size)
pred = pd.DataFrame(wnet_predict[-val_size:, -1, 0], \
            index=d_train[-val_size:].index,
            columns=['prediction'])

fig, ax = plt.subplots()
d_train.plot(label='observed',ax=ax)
pred.plot(ax=ax)
plt.legend()
plt.show()

# %%
rmse_train = math.sqrt(mean_squared_error(d_train[-val_size:], pred.prediction))
print("The root mean squared error is {}.".format(rmse_train))
# Out:
# The root mean squared error is 97.18141846975455.

# %%
wnet_forecast = model_forecast(wnet_model, pd.concat([d_train[-window_size:-1],d_test]).y.values[:, np.newaxis], window_size)
fcast = pd.DataFrame(wnet_forecast[:,-1,0], \
            index=d_test.index,
            columns=['forecast'])

fig, ax = plt.subplots()
d_test.plot(ax=ax)
fcast.plot(ax=ax)
plt.legend()
plt.show()

# %%
rmse_test = math.sqrt(mean_squared_error(d_test, fcast))
print("The root mean squared error is {}.".format(rmse_test))
# Out:
# The root mean squared error is 83.84925092137853.

# %%
mape = np.mean(np.abs(d_test.y.values - fcast.forecast.values) / d_test.y.values) * 100
print("The mean average percentage error is {}.".format(mape))
# Out:
# The mean average percentage error is 24.258742955552496.

# %%
error_vals.append(('Wavenet Model',rmse_train,rmse_test,mape))

# %%
errors = dict()
errors['model'] = []
errors['rmse_train'] = []
errors['rmse_test'] = []
errors['mape'] = []

for row in error_vals:
    errors['model'].append(row[0])
    errors['rmse_train'].append(row[1])
    errors['rmse_test'].append(row[2])
    errors['mape'].append(row[3])

pd.DataFrame(errors)
# Out:
#            model  rmse_train  rmse_test       mape
# 0   Linear Model   45.488170  42.628008  14.114272
# 1    Dense Model   42.974729  40.886176  14.012982
# 2      CNN Model   79.117042  64.411742  16.351113
# 3  Wavenet Model   97.181418  83.849251  24.258743

# %%
fig,ax = plt.subplots(4,1,figsize=(15,20))

d_train.plot(ax=ax[0], label='daily checkins')
lin_forecast = model_forecast(lin_model, pd.concat([d_train[-window_size:],d_test[:-1]]).y, window_size)[:, 0]
fcast = pd.DataFrame(dense_forecast, \
            index=d_test.index,
            columns=['forecast'])
fcast.plot(ax=ax[0])

d_train.plot(ax=ax[1], label='daily checkins')
dense_forecast = model_forecast(den_model, pd.concat([d_train[-window_size:],d_test[:-1]]).y, window_size)[:, 0]
fcast = pd.DataFrame(dense_forecast, \
            index=d_test.index,
            columns=['forecast'])
fcast.plot(ax=ax[1])

d_train.plot(ax=ax[2], label='daily checkins')
cnn_forecast = model_forecast(cnn_model, pd.concat([d_train[-window_size:-1],d_test]).y.values[:, np.newaxis], window_size)
fcast = pd.DataFrame(cnn_forecast[:,-1,0], \
            index=d_test.index,
            columns=['forecast'])
fcast.plot(ax=ax[2])

d_train.plot(ax=ax[3], label='daily checkins')
wnet_forecast = model_forecast(wnet_model, pd.concat([d_train[-window_size:-1],d_test]).y.values[:, np.newaxis], window_size)
fcast = pd.DataFrame(wnet_forecast[:,-1,0], \
            index=d_test.index,
            columns=['forecast'])
fcast.plot(ax=ax[3])

ax[0].set(title='Linear Model (TensorFlow)',xlabel='',ylabel='number of checkins')
ax[1].set(title='Dense Model (TensorFlow)',xlabel='',ylabel='number of checkins')
ax[2].set(title='CNN Model (TensorFlow)',xlabel='',ylabel='number of checkins')
ax[3].set(title='Wavenet Model (TensorFlow)',xlabel='Time (daily)',ylabel='number of checkins')
plt.show()
